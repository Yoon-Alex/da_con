# %%
import os
import sys 
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.animation as animation

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'notebook_connected'

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler 
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
import warnings  
warnings.filterwarnings('ignore')

# %% [markdown]
# 2. 주제
#
# - 포스트 코로나 시대 유망 품목 및 산업 발굴
#
# - 코로나로 인한 국민의 생활/소비의 변화 파악

# %%
file_list = os.listdir('./KT_data')
file_list
# Out:
# ['adstrd_master.csv',
#  'card.csv',
#  'Case.csv',
#  'COVID_19',
#  'COVID_eng_kor_table.xlsx',
#  'Data-Science-for-COVID-19',
#  'delivery.csv',
#  'fpopl.csv',
#  'index.csv',
#  'Patient',
#  'Policy.csv',
#  'Region.csv',
#  'SearchTrend.csv',
#  'SeoulFloating.csv',
#  'Time',
#  'Weather.csv']

# %%
direc = "./KT_data/"

fpopl_columns = pd.read_csv(direc + "fpopl.csv", nrows = 1) # 행정동 유동인구

dtype = dict(zip(list(fpopl_columns.columns), ['object'] * 5 + ['int']))

fpopl = pd.read_csv(direc + "fpopl.csv", dtype = dtype) # 행정동 유동인구

fpopl.head() # 24시간 구분, 성별, 연령, 시군구, 유동인구

# %%
fpopl.base_ymd.min(), fpopl.base_ymd.max() 

fpopl.popltn_cascnt.describe()
# Out:
# ('20200101', '20200616')

# %%
fpopl.query("base_ymd == '20200109'").adstrd_code.str.slice(0,2).unique() # 서울만
# Out:
# array(['11'], dtype=object)

# %%
fpopl.query("base_ymd == '20200109' \
            or base_ymd == '20200209' \
            or base_ymd == '20200309'").groupby(["base_ymd", fpopl.adstrd_code.str.slice(0,2) ]).agg({'popltn_cascnt': 'sum'})
# Out:
#                       popltn_cascnt
# base_ymd adstrd_code
# 20200109 11                58779586
# 20200209 11                42685609
# 20200309 11                51249534

# %% [markdown]
# ## 유동인구 수 변화
#
# 1. 코로나 이전과 이후의 유동인구 수 변화, 지역별 변화 확인
# 2. 남, 여 차이 존재하는지
# 3. 연령별 차이 존재하는지 (14살이하,  1524 , 2534, 3549, 5059, 6069, 70대 이상)
# 4. 하루 평균 유동인구 나타내기 , 9시 ~ 12시
# 결론: 국민의 생활 -> 유동인구가 줄어들고 거리두기를 지속하는 형태가 장기화 될 수 있음을 시사.

# %% [markdown]
# https://dailyheumsi.tistory.com/118#2.-plotly-express-%EC%82%AC%EC%9A%A9%ED%95%98%EA%B8%B0

# %% [markdown]
# ## 코로나 확진자와 유동인구수의 관계
# 1. 코로나 확진자와 유동인구수 상관관계 조사.
# 2. 코로나 사태 진정과 재확산의 기조의 증상과 현상
#
# 결론 : 이제 코로나 시대에서는 '' 할 것으로 보임.

# %%
# 하루 평균 유동인구 수 비교 
groupby_ymd = fpopl.groupby('base_ymd')

# %%
import cufflinks as cf 
cf.go_offline(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
daily_ = groupby_ymd.agg({'popltn_cascnt': 'mean'})

# %%
daily_.index = pd.to_datetime(daily_.index)

# %%
daily_.iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="d13702f3-a077-4084-b125-0986bde70651" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("
gungu.adstrd_code = gungu.adstrd_code.apply(lambda x : str(x)[:5])

seoul = gungu.drop_duplicates().query("brtc_nm == '서울특별시'").reset_index(drop=True)

# %%
seoul
# Out:
#    brtc_nm signgu_nm adstrd_code
# 0    서울특별시       종로구       11110
# 1    서울특별시        중구       11140
# 2    서울특별시       용산구       11170
# 3    서울특별시       성동구       11200
# 4    서울특별시       광진구       11215
# 5    서울특별시      동대문구       11230
# 6    서울특별시       중랑구       11260
# 7    서울특별시       성북구       11290
# 8    서울특별시       강북구       11305
# 9    서울특별시       도봉구       11320
# 10   서울특별시       노원구       11350
# 11   서울특별시       은평구       11380
# 12   서울특별시      서대문구       11410
# 13   서울특별시       마포구       11440
# 14   서울특별시       양천구       11470
# 15   서울특별시       강서구       11500
# 16   서울특별시       구로구       11530
# 17   서울특별시       금천구       11545
# 18   서울특별시      영등포구       11560
# 19   서울특별시       동작구       11590
# 20   서울특별시       관악구       11620
# 21   서울특별시       서초구       11650
# 22   서울특별시       강남구       11680
# 23   서울특별시       송파구       11710
# 24   서울특별시       강동구       11740

# %%
pivot.index = pd.to_datetime(pivot.index)

# %%
pivot.iplot("line")
# Out:
# <div>
#
#
#             <div id="70c07225-d2ac-42d6-b56e-021dfda0bf4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("70c07225-d2ac-42d6-b56e-021dfda0bf4b")) {
#                     Plotly.newPlot(
#                         '70c07225-d2ac-42d6-b56e-021dfda0bf4b',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "11110", "text": "", "type": "scatter", "x": ["2020-01-01", "2020-01-02", "2020-01-03", "2020-01-04", "2020-01-05", "2020-01-06", "2020-01-07", "2020-01-08", "2020-01-09", "2020-01-10", "2020-01-11", "2020-01-12", "2020-01-13", "2020-01-14", "2020-01-15", "2020-01-16", "2020-01-17", "2020-01-18", "2020-01-19", "2020-01-20", "2020-01-21", "2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30", "2020-01-31", "2020-02-01", "2020-02-02", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-08", "2020-02-09", "2020-02-10", "2020-02-11", "2020-02-12", "2020-02-13", "2020-02-14", "2020-02-15", "2020-02-16", "2020-02-17", "2020-02-18", "2020-02-19", "2020-02-20", "2020-02-21", "2020-02-22", "2020-02-23", "2020-02-24", "2020-02-25", "2020-02-26", "2020-02-27", "2020-02-28", "2020-02-29", "2020-03-01", "2020-03-02", "2020-03-03", "2020-03-04", "2020-03-05", "2020-03-06", "2020-03-07", "2020-03-08", "2020-03-09", "2020-03-10", "2020-03-11", "2020-03-12", "2020-03-13", "2020-03-14", "2020-03-15", "2020-03-16", "2020-03-17", "2020-03-18", "2020-03-19", "2020-03-20", "2020-03-21", "2020-03-22", "2020-03-23", "2020-03-24", "2020-03-25", "2020-03-26", "2020-03-27", "2020-03-28", "2020-03-29", "2020-03-30", "2020-03-31", "2020-04-01", "2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05", "2020-04-06", "2020-04-07", "2020-04-08", "2020-04-09", "2020-04-10", "2020-04-11", "2020-04-12", "2020-04-13", "2020-04-14", "2020-04-15", "2020-04-16", "2020-04-17", "2020-04-18", "2020-04-19", "2020-04-20", "2020-04-21", "2020-04-22", "2020-04-23", "2020-04-24", "2020-04-25", "2020-04-26", "2020-04-27", "2020-04-28", "2020-04-29", "2020-04-30", "2020-05-01", "2020-05-02", "2020-05-03", "2020-05-04", "2020-05-05", "2020-05-06", "2020-05-07", "2020-05-08", "2020-05-09", "2020-05-10", "2020-05-11", "2020-05-12", "2020-05-13", "2020-05-14", "2020-05-15", "2020-05-16", "2020-05-17", "2020-05-18", "2020-05-19", "2020-05-20", "2020-05-21", "2020-05-22", "2020-05-23", "2020-05-24", "2020-05-25", "2020-05-26", "2020-05-27", "2020-05-28", "2020-05-29", "2020-05-30", "2020-05-31", "2020-06-01", "2020-06-02", "2020-06-03", "2020-06-04", "2020-06-05", "2020-06-06", "2020-06-07", "2020-06-08", "2020-06-09", "2020-06-10", "2020-06-11", "2020-06-12", "2020-06-13", "2020-06-14", "2020-06-15", "2020-06-16"], "y": [1289867, 1883301, 2008281, 1685580, 1342674, 1888963, 1838624, 1970437, 2021552, 2053194, 1840581, 1379711, 1926450, 1983345, 2022830, 2009244, 2055871, 1795226, 1314151, 1952754, 2015876, 2011720, 1802447, 1104156, 1289880, 1280255, 1087222, 1743965, 1933086, 1942169, 1942091, 1420580, 1107299, 1785258, 1808964, 1766214, 1781410, 1838214, 1393994, 1116141, 1809563, 1896237, 1787346, 1917217, 1991281, 1575248, 1105105, 1716020, 1833184, 1897413, 1874374, 1803776, 1268937, 1009921, 1657497, 1569851, 1640645, 1620082, 1519547, 1125487, 842888, 1519114, 1535639, 1505679, 1538372, 1596899, 1161188, 955561, 1575967, 1478260, 1609002, 1591709, 1600550, 1211104, 930505, 1566879, 1576915, 1644887, 1531408, 1675035, 1273278, 1035219, 1609382, 1653449, 1680112, 1624155, 1669353, 1289399, 1036297, 1628285, 1674311, 1661954, 1664417, 1698709, 1290417, 1021713, 1641270, 1682891, 1692486, 1692412, 1736880, 1341079, 1032175, 1688996, 1758894, 1268528, 1727369, 1634319, 1454332, 972753, 1653087, 1725197, 1693864, 1752882, 1811730, 1463668, 1208056, 1762791, 1845179, 1918094, 1505197, 1478040, 1414656, 1194301, 1698465, 1344137, 1855561, 1900018, 1896864, 1254332, 1176255, 1776304, 1813018, 1859230, 1842434, 1701588, 1448637, 1216431, 1691099, 1751603, 1911957, 1906629, 1905854, 1593976, 1174658, 1821528, 1829224, 1935012, 1903166, 2063526, 1648920, 1273018, 1935838, 1910905, 2024916, 2026542, 2090511, 1561282, 1265683, 1920693, 1977481, 195 ...

# %%
# http://opengov.seoul.go.kr/analysis/11143108
pivot[['11680', '11140']].iplot("line")
# Out:
# <div>
#
#
#             <div id="6a774d92-9d96-4cff-8d37-2e3f338a376c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("
258.714285715, 4711511.0, 4706924.714285715, 4742542.0, 4776890.714285715, 4803982.857142857, 4852558.714285715, 4887110.714285715, 4953836.714285715, 5030715.857142857, 5099782.714285715, 5127562.285714285, 5123522.142857143, 5126203.428571428, 5181049.714285715, 5197764.857142857, 5173371.428571428, 5125598.857142857, 5103432.0, 5101199.0, 5010574.285714285, 4903809.142857143, 4785460.428571428, 4642289.285714285, 4537039.0, 4443587.857142857, 4382684.857142857, 4356654.857142857, 4310447.142857143, 4290265.714285715, 4322484.142857143, 4346409.428571428, 4394631.714285715, 4408283.285714285, 4383008.142857143, 4405788.142857143, 4416273.428571428, 4418368.142857143, 4442294.142857143, 4431899.142857143, 4405430.0, 4421751.714285715, 4414856.714285715, 4376509.571428572, 4367889.285714285, 4339849.285714285, 4339195.428571428, 4353853.571428572, 4374643.0, 4385384.714285715, 4403898.14285714 ...

# %%
pd.DataFrame(fpopl.popltn_cascnt.describe(), dtype = 'int')

# %%
# 1. 유동인구 데이터 분석

# %%
card = pd.read_csv("./KT_data/card.csv")

# %%
card.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200104   1174066000      성내3동                  7041
# 1      20200104   1174066000      성내3동                  7022
# 2      20200104   1174066000      성내3동                  7021
# 3      20200104   1174066000      성내3동                  7020
# 4      20200104   1174066000      성내3동                  6110
#
#   mrhst_induty_cl_nm selng_cascnt   salamt
# 0                 약국          463  5843230
# 1               치과의원           33  7835550
# 2                한의원           53  4589800
# 3                 의원          339  9267240
# 4              자동차정비           19  4441000

# %%
card.query("selng_cascnt != '석재' and salamt != '석재'", inplace = True)

# %%
for column in card.columns:
    if column in ['selng_cascnt', 'salamt'] :
        card[[column]] = card[[column]].astype("int")
    else :
        card[[column]] = card[[column]].astype("object")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-4e7d17df26f2> in <module>
#       1 for column in card.columns:
#       2     if column in ['selng_cascnt', 'salamt'] :
# ----> 3         card[[column]] = card[[column]].astype("int")
#       4     else :
#       5         card[[column]] = card[[column]].astype("object")
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy)
#     707         # work around NumPy brokenness, #1987
#     708         if np.issubdtype(dtype.type, np.integer):
# --> 709             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     710
#     711         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src\util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: '영상물'

# %%
card.head()
# Out:
#   receipt_dttm adstrd_code adstrd_nm mrhst_induty_cl_code mrhst_induty_cl_nm  \
# 0     20200104  1174066000      성내3동                 7041                 약국
# 1     20200104  1174066000      성내3동                 7022               치과의원
# 2     20200104  1174066000      성내3동                 7021                한의원
# 3     20200104  1174066000      성내3동                 7020                 의원
# 4     20200104  1174066000      성내3동                 6110              자동차정비
#
#   selng_cascnt   salamt
# 0          463  5843230
# 1           33  7835550
# 2           53  4589800
# 3          339  9267240
# 4           19  4441000

# %%
card = pd.read_csv("./KT_data/card.csv", dtype = dtype)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array from dtype('O') to dtype('int32') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-a70f07113204> in <module>
# ----> 1 card = pd.read_csv("./KT_data/card.csv", dtype = dtype)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# ValueError: invalid literal for int() with base 10: '석재'

# %%
pd.DataFrame(card.describe(), dtype = 'int')
# Out:
#        receipt_dttm  adstrd_code  mrhst_induty_cl_code
# count       3777647      3777647               3777647
# mean       20200377   1144511491                  6077
# std             146     19188646                  2387
# min        20200104   1111051500                  1001
# 25%        20200229   1126069000                  4201
# 50%        20200406   1147054000                  7020
# 75%        20200512   1162063000                  8021
# max        20200614   1174070000                  9998

# %% [markdown]
# ## 카드데이터 분석
#
# 1. 코로나 이전과 이후 가장 많이 차이가 나는 빈도 수 분석, 매출 분석
# 2. 코로나 이후 급상승한 트렌드 분석
# 3.

# %%
card.

# %%
card.adstrd_code.str.slice(start=0, stop=5).unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-c611f75e3a20> in <module>
# ----> 1 card.adstrd_code.str.slice(start=0, stop=5).unique
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    1893
#    1894     def __init__(self, data):
# -> 1895         self._validate(data)
#    1896         self._is_categorical = is_categorical_dtype(data)
#    1897
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\strings.py in _validate(data)
#    1915             # (instead of test for object dtype), but that isn't practical for
#    1916             # performance reasons until we have a str dtype (GH 9343)
# -> 1917             raise AttributeError("Can only use .str accessor with string "
#    1918                                  "values, which use np.object_ dtype in "
#    1919                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
card.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200104   1174066000      성내3동                  7041
# 1      20200104   1174066000      성내3동                  7022
# 2      20200104   1174066000      성내3동                  7021
# 3      20200104   1174066000      성내3동                  7020
# 4      20200104   1174066000      성내3동                  6110
#
#   mrhst_induty_cl_nm selng_cascnt   salamt
# 0                 약국          463  5843230
# 1               치과의원           33  7835550
# 2                한의원           53  4589800
# 3                 의원          339  9267240
# 4              자동차정비           19  4441000

# %%
card.groupby('selng_cascnt').salamt.sum().reset_index().sort_values(ascending=False)

# %%
delivery = pd.read_csv("./KT_data/delivery.csv")

# %%
covid_eng = pd.read_excel("./KT_data/COVID_eng_kor_table.xlsx")

# %%
df = './KT_data/COVID_19/' 
fu = {}
for direc in os.listdir('./KT_data/COVID_19'):
    fu[direc.split("/")[-1].replace(".csv",'')] = df+direc

# %%
for name, direc in fu.items():
    globals()['{}'.format(name.lower())] = pd.read_csv(direc)

# %%
case.head() # group: 집단 감염 유무

# %%
for i in case.columns:
    print(i)
    print(case.loc[:,i].nunique(),'가지 category속성')
    print(case.loc[:,i].unique())
    print("\n")

# %%
case.groupby("group").nunique()

# %%
case.query("group == True").sort_values("confirmed", ascending = False).head(10)

# %%
patientinfo.head()

# %%
policy.head()

# %%
region.head()

# %%
time.head()

# %%
timeage.head()

# %%
timegender.head()

# %%
timeprovince.head()
